# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# c1*((x1+b1)*sigma(x2+b2))+c2*(sigma(x1+b1)*tanh(x2+b2))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# d(y,z9)*d(z9,z6)*d(z6,c2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (d(y,z8)*d(z8,z7)*d(z7,z1)+d(y,z9)*d(z9,z3)*d(z3,z1))*d(z1,b1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (d(y, z8)*d(z8, z7)*d(z7, z4)*d(z4, z2)+d(y, z9)*d(z9, z6)*d(z6, z5)*d(z5,z2))*d(z2, b2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  tanh(x2+b2)*sigma(x1+b1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# sigma(x1+b1)*(1-sigma(x1+b1))*tanh(x2+b2)*c2+sigma(x2+b2)*c1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# c1 * (x1 + b1) * (sigma(x2 + b2)) * (1 - sigma(x2 + b2)) + c2 * sigma(x1 + b1) * (1 - (tanh(x2 + b2)**2))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# l

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (l.T*W).T

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# l*x.T

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2*X.T*(X*a-y)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# M>=N

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# N

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (X.T*X)^(-1)*X.T*y

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# X.T * X

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -N+M

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# X*X.T

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# [[-4,-1.333],[2,3.334]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# import torch
#
# w =torch.tensor([[5.,10.],[1.,2.]],requires_grad=True)  # put our code here
#
# function =torch.log(torch.log(w +7)).prod()  # put our code here
# function.backward()
#
# #print(w.grad) # Код для самопроверки

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# import torch
#
# w = torch.tensor([[5., 10.], [1., 2.]], requires_grad=True)
# alpha = 0.001
#
# for _ in range(500):
#     # critical: calculate the function inside the loop
#     function = (w + 7).log().log().prod()
#     function.backward()
#     w.data -= alpha * w.grad
#     w.grad.zero_() # put code here
#     # something is missing
#
# #print(w) # Код для самопроверки, не забудьте закомментировать перед

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# import torch
#
# w = torch.tensor([[5., 10.], [1., 2.]], requires_grad=True)
# alpha = 0.001
# optimizer =  torch.optim.SGD([w], lr=alpha)  # put our code here. Do not forget [] inside SGD constructor !!!!
#
# for _ in range(500):
#     # it's critical to calculate function inside the loop:
#     function = (w + 7).log().log().prod()
#     function.backward()
#     optimizer.step()
#     w.grad.zero_()
#     # something is missing here!
#
# #print(w) # Код для самопроверки

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1
