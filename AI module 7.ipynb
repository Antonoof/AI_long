# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# prod_i (p(x_i))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# C(M,N) * (p_d * (1-p_s))^M * ((1-p_d * (1-p_s))^(N-M))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
-M*log(p_d*(1-p_s))-(N-M)*log(1-p_d*(1-p_s))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 -M*log(p_d*(1-p_s))-(N-M)*log(1-p_d*(1-p_s))
#
# NameError: name 'M' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
-sum_i(m_i)*log(l)-log(exp(-k*l))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 -sum_i(m_i)*log(l)-log(exp(-k*l))
#
# NameError: name 'sum_i' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# sum_i(m_i)/k

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N*log(s)+sum_i((x_i-m)**2/(2*s**2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 N*log(s)+sum_i((x_i-m)**2/(2*s**2))
#
# NameError: name 'N' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# sum_i(x_i)/N

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sqrt(sum_i((x_i-m)^2)/N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sqrt(sum_i((x_i-m)^2)/N)
#
# NameError: name 'sqrt' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
log(p(x|l))+log(p(l))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 log(p(x|l))+log(p(l))
#
# NameError: name 'log' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sum_i((x_i -m)**2/2)+m**2/2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sum_i((x_i -m)**2/2)+m**2/2
#
# NameError: name 'sum_i' is not defined

# %% [markdown]
# ## В 7.3 можно скинуть любой символ и нажать отправить
# ![image.png](attachment:image.png)
